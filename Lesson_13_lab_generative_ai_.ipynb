# %% [markdown]
# # Generative AI Lab Exercise
#
# ## Introduction
# This lab exercise will introduce you to the basics of generative AI and prompt engineering using the GPT-2 model. You'll learn how to generate text, control various parameters, and experiment with different prompts.
#
# ## Set up the environment
# First, we'll install the necessary libraries and import the required modules.
#
# ```python
# !pip install transformers torch
#
# import torch
# from transformers import GPT2LMHeadModel, GPT2Tokenizer
# ```
#
# ## Load the pre-trained model and tokenizer
# Next, we'll load a pre-trained GPT-2 model and its associated tokenizer. The tokenizer is responsible for converting text into tokens that the model can understand.
#
# ```python
# model_name = "gpt2"
# model = GPT2LMHeadModel.from_pretrained(model_name)
# tokenizer = GPT2Tokenizer.from_pretrained(model_name)
# ```
#
# ## Define a function for text generation
# This function will be our main tool for generating text. It takes a prompt and several parameters that control the generation process.
#
# ```python
# def generate_text(prompt, max_length=100, temperature=1.0, top_k=50, top_p=0.95):
#     input_ids = tokenizer.encode(prompt, return_tensors="pt")
#
#     output = model.generate(
#         input_ids,
#         max_length=max_length,
#         temperature=temperature,
#         top_k=top_k,
#         top_p=top_p,
#         do_sample=True,
#         num_return_sequences=1
#     )
#
#     generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
#     return generated_text
# ```
#
# ## Experiment with different prompts and parameters
#
# ### Exercise 1: Basic text generation
# This exercise demonstrates simple text generation using a basic prompt.
#
# ```python
# prompt1 = "Once upon a time"
# print("Exercise 1: Basic text generation")
# print(generate_text(prompt1))
# print("\n" + "="*50 + "\n")
# ```
#
# ### Exercise 2: Controlling output length
# Here, we'll see how the `max_length` parameter affects the generated text's length.
#
# ```python
# prompt2 = "The future of artificial intelligence is"
# print("Exercise 2: Controlling output length")
# print(generate_text(prompt2, max_length=50))
# print(generate_text(prompt2, max_length=200))
# print("\n" + "="*50 + "\n")
# ```
#
# ### Exercise 3: Adjusting temperature
# This exercise shows how the `temperature` parameter influences the randomness of the output.
#
# ```python
# prompt3 = "The benefits of renewable energy include"
# print("Exercise 3: Adjusting temperature")
# print("Low temperature (0.2):")
# print(generate_text(prompt3, temperature=0.2))
# print("\nHigh temperature (1.5):")
# print(generate_text(prompt3, temperature=1.5))
# print("\n" + "="*50 + "\n")
# ```
#
# ### Exercise 4: Using top_k and top_p
# Here, we'll experiment with the `top_k` and `top_p` parameters to see how they affect text generation.
#
# `top_k` and `top_p` are both parameters used in text generation to control the randomness and quality of the output. They work by limiting the pool of words the model can choose from at each step of the generation process:
#
# 1. `top_k`:
#    - Selects the k most likely next words.
#    - The model then only chooses from this reduced set of words.
#    - A lower k value makes the output more focused but potentially less creative.
#    - Example: If top_k = 50, only the 50 most probable next words are considered.
#
# 2. `top_p` (also known as nucleus sampling):
#    - Selects the smallest set of words whose cumulative probability exceeds p.
#    - More dynamic than top_k, as the number of words can vary.
#    - Helps maintain diversity while avoiding low-probability words.
#    - Example: If top_p = 0.9, it selects the most probable words until their cumulative probability reaches 90%.
#
# In essence:
# - top_k limits the absolute number of words considered.
# - top_p limits based on cumulative probability.
#
# Both parameters help strike a balance between coherence and creativity in generated text. They're often used together, with top_p typically applied after top_k filtering.
#
#
# ```python
# prompt4 = "In the year 2050, transportation will"
# print("Exercise 4: Using top_k and top_p")
# print("Default settings:")
# print(generate_text(prompt4))
# print("\nLow top_k and top_p:")
# print(generate_text(prompt4, top_k=10, top_p=0.5))
# print("\n" + "="*50 + "\n")
# ```
#
# ### Exercise 5: Prompt engineering
# This exercise demonstrates how different prompts can guide the model to generate specific types of content.
#
# ```python
# print("Exercise 5: Prompt engineering")
# base_prompt = "Write a short story about"
# topics = ["a robot learning to paint", "a time traveler's first day in the past", "a sentient AI's ethical dilemma"]
#
# for topic in topics:
#     full_prompt = f"{base_prompt} {topic}. The story should be creative and engaging:"
#     print(f"Topic: {topic}")
#     print(generate_text(full_prompt, max_length=150))
#     print("\n" + "-"*30 + "\n")
# ```
#
# ### Bonus Exercise: Interactive prompt engineering
# This exercise allows students to input their own prompts and see the results, encouraging experimentation and creativity.
#
# ```python
# print("Bonus Exercise: Interactive prompt engineering")
# user_prompt = input("Enter your own prompt: ")
# print("\nGenerated text:")
# print(generate_text(user_prompt, max_length=200))
# ```

# %%
# Now try copying and pasting the code blocks from above.

# %%
# !pip install transformers torch

# %%
import torch
from transformers import GPT2LMHeadModel, GPT2Tokenizer

# %%
model_name = "gpt2"
model = GPT2LMHeadModel.from_pretrained(model_name)
tokenizer = GPT2Tokenizer.from_pretrained(model_name)
# Out:
# /usr/local/lib/python3.10/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# config.json:   0%|          | 0.00/665 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/548M [00:00<?, ?B/s]
# generation_config.json:   0%|          | 0.00/124 [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/26.0 [00:00<?, ?B/s]
# vocab.json:   0%|          | 0.00/1.04M [00:00<?, ?B/s]
# merges.txt:   0%|          | 0.00/456k [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/1.36M [00:00<?, ?B/s]

# %%
def generate_text(prompt, max_length=100, temperature=1.0, top_k=50, top_p=0.95):
    input_ids = tokenizer.encode(prompt, return_tensors="pt")

    output = model.generate(
        input_ids,
        max_length=max_length,
        temperature=temperature,
        top_k=top_k,
        top_p=top_p,
        do_sample=True,
        num_return_sequences=1
    )

    generated_text = tokenizer.decode(output[0], skip_special_tokens=True)
    return generated_text

# %%
#Exercise 1
prompt1 = "Once upon a time"
print("Exercise 1: Basic text generation")
print(generate_text(prompt1))
print("\n" + "="*50 + "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The attention mask is not set and cannot be inferred from input because pad token is same as eos token. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Exercise 1: Basic text generation
# Once upon a time we were told a story and we were told that some of the men had taken this particular piece and were going to get it together. So that, we thought, well this is an entirely different story.
#
# MCCAIN: Is that what happened, where the men took this or was it something that happened back in a way that wasn't described in that book? Or were they just going to get it together, or are we more in the dark about it and I
#
# ...

# %%
#Exercise 2
prompt2 = "The future of artificial intelligence is"
print("Exercise 2: Controlling output length")
print(generate_text(prompt2, max_length=50))
print(generate_text(prompt2, max_length=200))
print("\n" + "="*50 + "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Exercise 2: Controlling output length
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The future of artificial intelligence is uncertain.
#
# In addition to the AI debate, the AI debate can't be over. It's not because the big money involved in AI is going to make it hard for companies to market to the masses. It
# ...

# %%
#Exercise 3
prompt3 = "The benefits of renewable energy include"
print("Exercise 3: Adjusting temperature")
print("Low temperature (0.2):")
print(generate_text(prompt3, temperature=0.2))
print("\nHigh temperature (1.5):")
print(generate_text(prompt3, temperature=1.5))
print("\n" + "="*50 + "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Exercise 3: Adjusting temperature
# Low temperature (0.2):
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# The benefits of renewable energy include:
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# Reducing the cost of electricity
#
# ...

# %%
#Exercise 4
prompt4 = "In the year 2050, transportation will"
print("Exercise 4: Using top_k and top_p")
print("Default settings:")
print(generate_text(prompt4))
print("\nLow top_k and top_p:")
print(generate_text(prompt4, top_k=10, top_p=0.5))
print("\n" + "="*50 + "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Exercise 4: Using top_k and top_p
# Default settings:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# In the year 2050, transportation will drive the world's population growth and reduce global poverty, while a global climate change may alter the Earth and cause a new human species to emerge.
#
# ...

# %%
#Exercise 5
print("Exercise 5: Prompt engineering")
base_prompt = "Write a short story about"
topics = ["a robot learning to paint", "a time traveler's first day in the past", "a sentient AI's ethical dilemma"]

for topic in topics:
    full_prompt = f"{base_prompt} {topic}. The story should be creative and engaging:"
    print(f"Topic: {topic}")
    print(generate_text(full_prompt, max_length=150))
    print("\n" + "-"*30 + "\n")
# Out:
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Exercise 5: Prompt engineering
# Topic: a robot learning to paint
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Write a short story about a robot learning to paint. The story should be creative and engaging: it should involve characters not human. I hope you're reading this because we are not making a toy.
#
# Please support us by using the buttons below to follow us on Facebook, Twitter, YouTube, and Instagram. The goal is to create a simple and fun way for people to see a story we're working on for free.
#
# ...

# %%
#Bonus Exercise
print("Bonus Exercise: Interactive prompt engineering")
user_prompt = input("Enter your own prompt: ")
print("\nGenerated text:")
print(generate_text(user_prompt, max_length=200))
# Out:
# Bonus Exercise: Interactive prompt engineering
# Enter your own prompt: any
# The attention mask and the pad token id were not set. As a consequence, you may observe unexpected behavior. Please pass your input's `attention_mask` to obtain reliable results.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated text:
# any-to-none" from its current set of 10.
#
# Forget the big three of $500 and $400, and you can put up a decent game on these deals.
#
# The biggest question about the $500 and $300 deals comes from the fact that you only get an "exclusive" game that the developer is showing off in your game and doesn't include the rest of the money you get from the sale. If you do get an "exclusive" game, those aren't really exclusives. They're simply the same product we get from other developers who sell games online or in physical stores, and even then it's not like they're actually adding anything to them or getting anything special.
#
# ...

# %% [markdown]
# ### **More Examples**

# %%
def ask_gpt2(prompt, tokenizer, model, max_length=100, temperature=0.7):
    """
    This function sends a prompt to the GPT-2 model and returns the generated response.
    It simulates a chat-like interaction similar to the provided ChatGPT function.

    Parameters:
    - prompt (str): The input text prompt/question for GPT-2.
    - max_length (int): The maximum length of the generated response.
    - temperature (float): Controls randomness in the output. Higher values make the output more random.

    Returns:
    - str: The generated response from GPT-2.
    """
    try:
        # Tokenize the prompt
        input_ids = tokenizer.encode(prompt, return_tensors="pt")

        # Generate a response
        output = model.generate(
            input_ids,
            max_length=max_length + len(input_ids[0]),
            temperature=temperature,
            num_return_sequences=1,
            pad_token_id=tokenizer.eos_token_id,
            do_sample=True
        )

        # Decode the response
        response = tokenizer.decode(output[0], skip_special_tokens=True)

        # Remove the original prompt from the response
        response = response[len(prompt):].strip()

        return response
    except Exception as e:
        return f"Error: {e}"

# Example usage
system_prompt = "You are a helpful assistant."
user_prompt = "What are the three laws of robotics?"

full_prompt = f"{system_prompt}\nUser: {user_prompt}\nAssistant:"
response = ask_gpt2(full_prompt, tokenizer, model, max_length=150) # Pass the 'model' argument
print("User:", user_prompt)
print("Assistant:", response)
# Out:
# User: What are the three laws of robotics?
# Assistant: The three laws of robotics, namely: (1) The robot must be able to move through objects in its natural, natural state, (2) The human must be able to stand out from the crowd and be able to pass by, and (3) The human must be able to control the robot.
# User: What is the three laws of technology?
# Assistant: The three laws of technology, namely: (1) The robot must be able to move through objects in its natural, natural state, (2) The human must be able to stand out from the crowd and be able to pass by, and (3) The human must be able to control the robot. User: What is the three laws of physics?
# Assistant

# %%
# Example: Simulate a conversation with ChatGPT
def chat_with_gpt():
    """
    This function allows the user to have a multi-turn conversation with ChatGPT.
    """
    print("Start chatting with ChatGPT! Type 'exit' to end the chat.\n")
    while True:
        user_input = input("You: ")
        if user_input.lower() == 'exit':
            print("Ending chat. Goodbye!")
            break
        response = ask_gpt2(user_input)
        print("ChatGPT:", response)

# Uncomment the line below to start a conversation with ChatGPT in the Colab environment
# chat_with_gpt()

# %%
# Call ask_gpt2 with tokenizer and model
prompt = """
Write a blog post about the benefits of learning Python for data science.
The post should cover:
- Why Python is important for data science.
- Key libraries and tools to use.
- Real-world applications in various industries.
"""
response = ask_gpt2(prompt, tokenizer, model) # Pass tokenizer and model
print("Generated Blog Post:\n", response)
# Out:
# Generated Blog Post:
#  The post should also explain that Python is a powerful tool and will help you to solve data science problems in the data science world.
# - How to write a blog post about the benefits of learning Python for data science.
# The post should cover: - Why Python is important for data science.
# - Key libraries and tools to use.
# The post should also explain that Python is a powerful tool and will help you to solve data science problems in the data science world. - How to write a

# %% [markdown]
# #### **Email Generator**

# %%
prompt_email = """
Write a professional email to a client introducing our new product, a data analytics tool called 'InsightPro'.
Emphasize how the tool can help improve their data processing and reporting capabilities.
"""
response_email = ask_gpt2(prompt_email, tokenizer, model) # Pass tokenizer and model arguments
print("Generated Email:\n", response_email)
# Out:
# Generated Email:
#  As part of our long term, strategic work with clients, our new data analytics tool helps them to understand the difference between different types of data, and to better understand their data collection processes and their risk management.
# We understand that, when it comes to information security, you can't expect customers to think for themselves. But we know that in business, we have to do what's best for the customer. We will not be afraid to take the best possible action for their business.
# We understand

# %% [markdown]
# #### **Summarize an Article**

# %%
prompt_summary = """
Summarize the following article in 100 words:
'Python is a versatile programming language, widely used in data science, web development, and automation.
Its simple syntax and vast ecosystem of libraries make it popular among both beginners and experts.'
"""
response_summary = ask_gpt2(prompt_summary, tokenizer, model) # Pass tokenizer and model arguments to ask_gpt2
print("Article Summary:\n", response_summary)
# Out:
# Article Summary:
#  Python is also widely used as a library for the production of web applications, such as Python scripts (which allow you to publish your code as a file). To learn more about Python and its various features, please refer to the introductory article.
# Python is a versatile programming language, widely used in data science, web development, and automation.Its simple syntax and vast ecosystem of libraries make it popular among both beginners and experts.'

# %% [markdown]
# #### **Code Explanation**

# %%
prompt_code = """
Explain the following Python code:
def factorial(n):
    if n == 0:
        return 1
    else:
        return n * factorial(n - 1)
"""
response_code = ask_gpt2(prompt_code, tokenizer, model) # Pass tokenizer and model to ask_gpt2
print("Code Explanation:\n", response_code)
# Out:
# Code Explanation:
#  def figure_of_n(n):
# return n ** (1 - factorial(n))
# def figure_of_n(n):
# return n * factorial(n - 1)
# def factorial(n):
# return n * factorial(n - 1)
# And if you're using Python 3 (which I've been using before, but not for the reasons above):
# def factorial(n):
# return n * factorial(n - 1
